# %%
from rottentomatoes import RottenTomatoes

# %%
tomatoes = RottenTomatoes("../raw")

# %%
reviews = tomatoes.get_ratings_by_title("Interstellarasdf")
# Out:
# 1

# %%
reviews.shape
# Out:
# (375, 2)

# %%
reviews
# Out:
#        creationDate reviewState
# 814194   2023-04-04       fresh
# 814195   2023-02-27       fresh
# 814196   2023-01-24      rotten
# 814197   2022-08-22       fresh
# 814198   2022-06-30       fresh
# ...             ...         ...
# 814564   2014-10-27       fresh
# 814565   2014-10-27      rotten
# 814566   2014-10-27       fresh
# 814567   2014-10-27       fresh
# 814568   2014-10-27      rotten
#
# [375 rows x 2 columns]

# %%
for r in reviews.values:
    print(r)
# Out:
# ['2023-04-04' 'fresh']
# ['2023-02-27' 'fresh']
# ['2023-01-24' 'rotten']
# ['2022-08-22' 'fresh']
# ['2022-06-30' 'fresh']
# ['2022-05-27' 'fresh']
# ['2022-02-11' 'fresh']
# ['2021-10-09' 'fresh']
# ['2021-08-10' 'fresh']
# ['2021-02-02' 'fresh']
# ['2020-12-04' 'rotten']
# ['2020-09-20' 'fresh']
# ['2020-09-12' 'fresh']
# ['2020-09-03' 'fresh']
# ['2020-08-26' 'rotten']
# ['2020-07-16' 'fresh']
# ['2020-07-07' 'fresh']
# ['2020-06-30' 'fresh']
# ['2020-06-26' 'fresh']
# ['2020-05-27' 'fresh']
# ['2020-03-26' 'fresh']
# ['2020-03-11' 'fresh']
# ['2020-01-09' 'rotten']
# ['2019-11-27' 'fresh']
# ['2019-11-20' 'rotten']
# ['2019-10-27' 'fresh']
# ['2019-09-06' 'fresh']
# ['2019-08-07' 'fresh']
# ['2019-08-02' 'fresh']
# ['2019-07-30' 'rotten']
# ['2019-07-16' 'fresh']
# ['2019-07-05' 'fresh']
# ['2019-05-31' 'fresh']
# ['2019-04-30' 'fresh']
# ['2019-04-03' 'fresh']
# ['2019-02-26' 'fresh']
# ['2019-02-02' 'rotten']
# ['2019-01-25' 'fresh']
# ['2019-01-25' 'rotten']
# ...
